# %% [markdown]
# #Learning Objectives:
#
#
# * Formulate  the problem
# * Load the Data
# * Data Exploration
# * Clean The Data
# * Discover and Visualize the Data to Gain Insights
# * Looking for Correlations
# * Prepare the Data for Machine Learning Algorithms
# * Save Cleaned Data and Download it

# %% [markdown]
# #Student Performance

# %% [markdown]
# <h3>About Data </h3>
#
#
#  <h2>Read Dataset Description</h2>
# We want to predict students performance in math in secondary education of two high schools. Please read the description of data set before start.
#
#  [Dataset Description](https://archive.ics.uci.edu/ml/datasets/student+performance)
#
# <h3>Import data</h3>
# <p>
# here link of raw data set: <a href="https://raw.githubusercontent.com/Ruqyai/Course-DS/master/math-raw.csv"> here</a>.
#
# </p>

# %% [markdown]
# #Formulate  the problem

# %% [markdown]
# We want to predict the Math Final Grade
#
# So How predict the Math Final Grade?!!
#
# Notice the data is labeled (**Supervised Learning**)
#
# Notice the desired output is number (**Regression**)

# %% [markdown]
# ###Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #Load the Data

# %% [markdown]
# ###Load the dataset

# %%
file_path = '/content/math-raw.csv'

# %%
df = pd.read_csv(file_path)
df
# Out:
#     school     sex   age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0       GP       F  18.0       U     GT3       A     4     4   at_home
# 1       GP       F  17.0       U     GT3       T     1     1   at_home
# 2       GP  Female  15.0       U     LE3       T     1     1   at_home
# 3       GP       F  15.0       U     GT3       T     4     2    health
# 4       GP       F  16.0       U     GT3       T     3     3     other
# ..     ...     ...   ...     ...     ...     ...   ...   ...       ...
# 390     MS       M  20.0       U     LE3       A     2     2  services
# 391     MS       M  17.0       U     LE3       T     3     1  services
# 392     MS       M  21.0       R     GT3       T     1     1     other
# 393     MS       M  18.0       R     LE3       T     3     2  services
# 394     MS       M  19.0       U     LE3       T     1     1     other
#
#          Fjob  ... famrel freetime  goout  Dalc  Walc health absences    G1  \
# 0     teacher  ...      4        ?      4     1     1      3      NaN   5.0
# 1       other  ...      5        ?      3     1     1      3      NaN   5.0
# 2       other  ...      4        3      2     2     3      3     10.0   7.0
# 3    services  ...      3        2      2     1     1      5      2.0  15.0
# 4       other  ...      4        3      2     1     2      5      4.0   6.0
# ..        ...  ...    ...      ...    ...   ...   ...    ...      ...   ...
# 390  services  ...      5        5      4     4     5      4     11.0   9.0
# 391  services  ...      2        4      5     3     4      2      3.0  14.0
# 392     other  ...      5        5      3     3     3      3      3.0  10.0
# 393     other  ...      4        4      1     3     4      5      0.0  11.0
# 394   at_home  ...      3        2      3     3     3      5      5.0   8.0
#
#      G2  G3
# 0     6   6
# 1     5   6
# 2     8  10
# 3    14  15
# 4    10  10
# ..   ..  ..
# 390   9   9
# 391  16  16
# 392   8   7
# 393  12  10
# 394   9   9
#
# [395 rows x 33 columns]

# %% [markdown]
# #Clean  the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      373 non-null    object
#  1   sex         394 non-null    object
#  2   age         394 non-null    float64
#  3   address     394 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    393 non-null    float64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
#  19  nursery     395 non-null    object
#  20  higher      395 non-null    object
#  21  internet    395 non-null    object
#  22  romantic    395 non-null    object
#  23  famrel      395 non-null    int64
#  24  freetime    395 non-null    object
#  25  goout       395 non-null    int64
#  26  Dalc        395 non-null    int64
#  27  Walc        395 non-null    int64
#  28  health      395 non-null    int64
#  29  absences    393 non-null    float64
#  30  G1          393 non-null    float64
#  31  G2          395 non-null    int64
#  32  G3          395 non-null    int64
# dtypes: float64(4), int64(11), object(18)
# memory usage: 102.0+ KB

# %% [markdown]
# ##Missing  Values

# %% [markdown]
# ## Identify and handle missing values

# %% [markdown]
# As we can see, several question marks appeared in the dataframe; those are missing values which may hinder our further analysis.
# <div>So, how do we identify all those missing values and deal with them?</div>
#
#
# <h1>How to work with missing data?</h1>
#
# Steps for working with missing data:
# <ol>
#     <li>identify missing data</li>
#     <li>deal with missing data</li>
#     <li>correct data format</li>
# </ol>

# %% [markdown]
# <h1 id="identify_missing_values">1. Identify missing values</h1>

# %%
df.isnull().sum()
# Out:
# school        22
# sex            1
# age            1
# address        1
# famsize        0
# Pstatus        0
# Medu           0
# Fedu           0
# Mjob           0
# Fjob           0
# reason         0
# guardian       0
# traveltime     0
# studytime      0
# failures       2
# schoolsup      0
# famsup         0
# paid           0
# activities     0
# nursery        0
# higher         0
# internet       0
# romantic       0
# famrel         0
# freetime       0
# goout          0
# Dalc           0
# Walc           0
# health         0
# absences       2
# G1             2
# G2             0
# G3             0
# dtype: int64

# %%
sns.heatmap(df.isnull(), cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
#
#    <h4>Convert "?" to NaN</h4>In the house dataset, missing data comes with the question mark "?".We replace "?" with NaN (Not a Number), which is Python's default missing value marker, for reasons of computational speed and convenience. Here we use the function:  <pre>.replace(A, B, inplace = True) </pre>to replace A by B

# %%
# replace "?" to NaN
df.replace("?", np.nan, inplace = True)
df.head(10)
# Out:
#   school     sex   age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0     GP       F  18.0       U     GT3       A     4     4   at_home
# 1     GP       F  17.0       U     GT3       T     1     1   at_home
# 2     GP  Female  15.0       U     LE3       T     1     1   at_home
# 3     GP       F  15.0       U     GT3       T     4     2    health
# 4     GP       F  16.0       U     GT3       T     3     3     other
# 5     GP    Male  16.0       U     LE3       T     4     3  services
# 6     GP       M  16.0       U     LE3       T     2     2     other
# 7    NaN     NaN   NaN     NaN     GT3       A     4     4     other
# 8    NaN       M  15.0       U     LE3       A     3     2  services
# 9    NaN       M  15.0       U     GT3       T     3     4     other
#
#        Fjob  ... famrel freetime  goout  Dalc  Walc health absences    G1  G2  \
# 0   teacher  ...      4      NaN      4     1     1      3      NaN   5.0   6
# 1     other  ...      5      NaN      3     1     1      3      NaN   5.0   5
# 2     other  ...      4        3      2     2     3      3     10.0   7.0   8
# 3  services  ...      3        2      2     1     1      5      2.0  15.0  14
# 4     other  ...      4        3      2     1     2      5      4.0   6.0  10
# 5     other  ...      5        4      2     1     2      5     10.0  15.0  15
# 6     other  ...      4        4      4     1     1      3      0.0  12.0  12
# 7   teacher  ...      4        1      4     1     1      1      6.0   6.0   5
# 8     other  ...      4        2      2     1     1      1      0.0  16.0  18
# 9     other  ...      5        5      1     1     1      5      0.0  14.0  15
#
#    G3
# 0   6
# 1   6
# 2  10
# 3  15
# 4  10
# 5  15
# 6  11
# 7   6
# 8  19
# 9  15
#
# [10 rows x 33 columns]

# %%
df.isnull().sum()
# Out:
# school        22
# sex            1
# age            1
# address        1
# famsize        0
# Pstatus        0
# Medu           0
# Fedu           0
# Mjob           0
# Fjob           0
# reason         0
# guardian       0
# traveltime     0
# studytime      0
# failures       2
# schoolsup      0
# famsup         0
# paid           0
# activities     0
# nursery        0
# higher         0
# internet       0
# romantic       0
# famrel         0
# freetime       2
# goout          0
# Dalc           0
# Walc           0
# health         0
# absences       2
# G1             2
# G2             0
# G3             0
# dtype: int64

# %% [markdown]
# <h1 id="deal_missing_values">2. Deal with missing data</h1>
# <b>How to deal with missing data?</b>
#
# <ol>
#     <li>drop data<br>
#         a. drop the whole row<br>
#         b. drop the whole column
#     </li>
#     <li>replace data (impute)<br>
#         a. replace it by mean or median <br>
#         b. replace it by frequency<br>
#         c. replace it based on inference or other functions
#     </li>
# </ol>

# %% [markdown]
# <h3>Drop the whole row</h3>

# %%
# TODO:Drop the whole row

# %% [markdown]
# <h3>Drop the whole column</h3>

# %%
# TODO: Drop the whole column

# %%
# use mode
df['school'].fillna(df['school'].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_5773/44812250.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['school'].fillna(df['school'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# school        0
# sex           1
# age           1
# address       1
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      2
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      2
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      2
# G1            2
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# <h3> Replace by sklearn.impute </h3>

# %%
from sklearn.impute import SimpleImputer
imr = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
df['sex'] = imr.fit_transform(df[['sex']]).ravel()

# %%
imr = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
df['address'] = imr.fit_transform(df[['address']]).ravel()

# %%
imr_num = SimpleImputer(missing_values=np.nan, strategy='median')
df[['age', 'failures', 'freetime', 'absences', 'G1']] = imr_num.fit_transform(df[['age', 'failures', 'freetime', 'absences', 'G1']])

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# <h3>Replace by frequency</h3>

# %%
# TODO: Replace by frequency
df['school'].value_counts()
# Out:
# school
# GP    349
# MS     46
# Name: count, dtype: int64

# %%
df
# Out:
#     school     sex   age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0       GP       F  18.0       U     GT3       A     4     4   at_home
# 1       GP       F  17.0       U     GT3       T     1     1   at_home
# 2       GP  Female  15.0       U     LE3       T     1     1   at_home
# 3       GP       F  15.0       U     GT3       T     4     2    health
# 4       GP       F  16.0       U     GT3       T     3     3     other
# ..     ...     ...   ...     ...     ...     ...   ...   ...       ...
# 390     MS       M  20.0       U     LE3       A     2     2  services
# 391     MS       M  17.0       U     LE3       T     3     1  services
# 392     MS       M  21.0       R     GT3       T     1     1     other
# 393     MS       M  18.0       R     LE3       T     3     2  services
# 394     MS       M  19.0       U     LE3       T     1     1     other
#
#          Fjob  ... famrel freetime  goout  Dalc  Walc health absences    G1  \
# 0     teacher  ...      4      3.0      4     1     1      3      4.0   5.0
# 1       other  ...      5      3.0      3     1     1      3      4.0   5.0
# 2       other  ...      4      3.0      2     2     3      3     10.0   7.0
# 3    services  ...      3      2.0      2     1     1      5      2.0  15.0
# 4       other  ...      4      3.0      2     1     2      5      4.0   6.0
# ..        ...  ...    ...      ...    ...   ...   ...    ...      ...   ...
# 390  services  ...      5      5.0      4     4     5      4     11.0   9.0
# 391  services  ...      2      4.0      5     3     4      2      3.0  14.0
# 392     other  ...      5      5.0      3     3     3      3      3.0  10.0
# 393     other  ...      4      4.0      1     3     4      5      0.0  11.0
# 394   at_home  ...      3      2.0      3     3     3      5      5.0   8.0
#
#      G2  G3
# 0     6   6
# 1     5   6
# 2     8  10
# 3    14  15
# 4    10  10
# ..   ..  ..
# 390   9   9
# 391  16  16
# 392   8   7
# 393  12  10
# 394   9   9
#
# [395 rows x 33 columns]

# %% [markdown]
# <h1 id="correct_data_format">3. Correct data format</h1>
# <b>We are almost there!</b>
# <p>The last step in data cleaning is checking and making sure that all data is in the correct format (int, float, text or other).</p>
#
# In Pandas, we use
# <p><b>.dtype</b> to check the data type</p>
# <p><b>.astype</b> to change the data type</p>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    float64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    float64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
#  19  nursery     395 non-null    object
#  20  higher      395 non-null    object
#  21  internet    395 non-null    object
#  22  romantic    395 non-null    object
#  23  famrel      395 non-null    int64
#  24  freetime    395 non-null    float64
#  25  goout       395 non-null    int64
#  26  Dalc        395 non-null    int64
#  27  Walc        395 non-null    int64
#  28  health      395 non-null    int64
#  29  absences    395 non-null    float64
#  30  G1          395 non-null    float64
#  31  G2          395 non-null    int64
#  32  G3          395 non-null    int64
# dtypes: float64(5), int64(11), object(17)
# memory usage: 102.0+ KB

# %%
df[['G2', 'G3']].dtypes
# Out:
# G2    int64
# G3    int64
# dtype: object

# %%
df['G2'] = df['G2'].astype("float")
df['G3'] = df['G3'].astype("float")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    float64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    float64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
#  19  nursery     395 non-null    object
#  20  higher      395 non-null    object
#  21  internet    395 non-null    object
#  22  romantic    395 non-null    object
#  23  famrel      395 non-null    int64
#  24  freetime    395 non-null    float64
#  25  goout       395 non-null    int64
#  26  Dalc        395 non-null    int64
#  27  Walc        395 non-null    int64
#  28  health      395 non-null    int64
#  29  absences    395 non-null    float64
#  30  G1          395 non-null    float64
#  31  G2          395 non-null    float64
#  32  G3          395 non-null    float64
# dtypes: float64(7), int64(9), object(17)
# memory usage: 102.0+ KB

# %% [markdown]
# <h3>Remove any duplicates</h3>

# %%
# TODO: Remove any duplicates
df = df.drop_duplicates()

# %%
df
# Out:
#     school     sex   age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0       GP       F  18.0       U     GT3       A     4     4   at_home
# 1       GP       F  17.0       U     GT3       T     1     1   at_home
# 2       GP  Female  15.0       U     LE3       T     1     1   at_home
# 3       GP       F  15.0       U     GT3       T     4     2    health
# 4       GP       F  16.0       U     GT3       T     3     3     other
# ..     ...     ...   ...     ...     ...     ...   ...   ...       ...
# 390     MS       M  20.0       U     LE3       A     2     2  services
# 391     MS       M  17.0       U     LE3       T     3     1  services
# 392     MS       M  21.0       R     GT3       T     1     1     other
# 393     MS       M  18.0       R     LE3       T     3     2  services
# 394     MS       M  19.0       U     LE3       T     1     1     other
#
#          Fjob  ... famrel freetime  goout  Dalc  Walc health absences    G1  \
# 0     teacher  ...      4      3.0      4     1     1      3      4.0   5.0
# 1       other  ...      5      3.0      3     1     1      3      4.0   5.0
# 2       other  ...      4      3.0      2     2     3      3     10.0   7.0
# 3    services  ...      3      2.0      2     1     1      5      2.0  15.0
# 4       other  ...      4      3.0      2     1     2      5      4.0   6.0
# ..        ...  ...    ...      ...    ...   ...   ...    ...      ...   ...
# 390  services  ...      5      5.0      4     4     5      4     11.0   9.0
# 391  services  ...      2      4.0      5     3     4      2      3.0  14.0
# 392     other  ...      5      5.0      3     3     3      3      3.0  10.0
# 393     other  ...      4      4.0      1     3     4      5      0.0  11.0
# 394   at_home  ...      3      2.0      3     3     3      5      5.0   8.0
#
#        G2    G3
# 0     6.0   6.0
# 1     5.0   6.0
# 2     8.0  10.0
# 3    14.0  15.0
# 4    10.0  10.0
# ..    ...   ...
# 390   9.0   9.0
# 391  16.0  16.0
# 392   8.0   7.0
# 393  12.0  10.0
# 394   9.0   9.0
#
# [395 rows x 33 columns]

# %% [markdown]
# <h3>Data Standardization</h3>
# <p>
# Data is usually collected from different agencies with different formats.
# (Data Standardization is also a term for a particular type of data normalization)
# </p>
#
# <b>What is Standardization?</b>
# <p>Standardization is the process of transforming data into a common format which allows the researcher to make the meaningful comparison.
# </p>

# %%
df['sex'].unique()
# Out:
# array(['F', 'Female', 'Male', 'M'], dtype=object)

# %%
df.replace("Female", 'F', inplace = True)
df.replace("Male", 'M', inplace = True)

# %% [markdown]
# <h3>Data Normalization </h3>
#
# <b>Why normalization?</b>
# <p>Normalization is the process of transforming values of several variables into a similar range. Typical normalizations include scaling the variable so the variable average is 0, scaling the variable so the variance is 1, or scaling variable so the variable values range from 0 to 1
# </p>

# %%
from sklearn.preprocessing import MinMaxScaler

numeric_cols = ['age', 'failures', 'freetime', 'absences', 'G1', 'G2', 'G3']
min_max_scaler = MinMaxScaler()
df[numeric_cols] = min_max_scaler.fit_transform(df[numeric_cols])

# %%
df[['age', 'failures', 'freetime', 'absences', 'G1', 'G2', 'G3']]
# Out:
#           age  failures  freetime  absences      G1        G2    G3
# 0    0.428571  0.000000      0.50  0.053333  0.1250  0.315789  0.30
# 1    0.285714  0.000000      0.50  0.053333  0.1250  0.263158  0.30
# 2    0.000000  1.000000      0.50  0.133333  0.2500  0.421053  0.50
# 3    0.000000  0.000000      0.25  0.026667  0.7500  0.736842  0.75
# 4    0.142857  0.000000      0.50  0.053333  0.1875  0.526316  0.50
# ..        ...       ...       ...       ...     ...       ...   ...
# 390  0.714286  0.666667      1.00  0.146667  0.3750  0.473684  0.45
# 391  0.285714  0.000000      0.75  0.040000  0.6875  0.842105  0.80
# 392  0.857143  1.000000      1.00  0.040000  0.4375  0.421053  0.35
# 393  0.428571  0.000000      0.75  0.000000  0.5000  0.631579  0.50
# 394  0.571429  0.000000      0.25  0.066667  0.3125  0.473684  0.45
#
# [395 rows x 7 columns]

# %%
df
# Out:
#     school sex       age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0       GP   F  0.428571       U     GT3       A     4     4   at_home
# 1       GP   F  0.285714       U     GT3       T     1     1   at_home
# 2       GP   F  0.000000       U     LE3       T     1     1   at_home
# 3       GP   F  0.000000       U     GT3       T     4     2    health
# 4       GP   F  0.142857       U     GT3       T     3     3     other
# ..     ...  ..       ...     ...     ...     ...   ...   ...       ...
# 390     MS   M  0.714286       U     LE3       A     2     2  services
# 391     MS   M  0.285714       U     LE3       T     3     1  services
# 392     MS   M  0.857143       R     GT3       T     1     1     other
# 393     MS   M  0.428571       R     LE3       T     3     2  services
# 394     MS   M  0.571429       U     LE3       T     1     1     other
#
#          Fjob  ... famrel freetime  goout  Dalc  Walc health  absences  \
# 0     teacher  ...      4     0.50      4     1     1      3  0.053333
# 1       other  ...      5     0.50      3     1     1      3  0.053333
# 2       other  ...      4     0.50      2     2     3      3  0.133333
# 3    services  ...      3     0.25      2     1     1      5  0.026667
# 4       other  ...      4     0.50      2     1     2      5  0.053333
# ..        ...  ...    ...      ...    ...   ...   ...    ...       ...
# 390  services  ...      5     1.00      4     4     5      4  0.146667
# 391  services  ...      2     0.75      5     3     4      2  0.040000
# 392     other  ...      5     1.00      3     3     3      3  0.040000
# 393     other  ...      4     0.75      1     3     4      5  0.000000
# 394   at_home  ...      3     0.25      3     3     3      5  0.066667
#
#          G1        G2    G3
# 0    0.1250  0.315789  0.30
# 1    0.1250  0.263158  0.30
# 2    0.2500  0.421053  0.50
# 3    0.7500  0.736842  0.75
# 4    0.1875  0.526316  0.50
# ..      ...       ...   ...
# 390  0.3750  0.473684  0.45
# 391  0.6875  0.842105  0.80
# 392  0.4375  0.421053  0.35
# 393  0.5000  0.631579  0.50
# 394  0.3125  0.473684  0.45
#
# [395 rows x 33 columns]

# %% [markdown]
# ---
#
# ---

# %% [markdown]
# # Exploratory Data Analysis (EDA) and Data Visualization

# %% [markdown]
# Categorical variables are variables that describe a 'characteristic' of a data unit, and are selected from a small group of categories. The categorical variables can have the type "object" or "int64". A good way to visualize categorical variables is by using boxplots.

# %% [markdown]
# <h3>Identify Outliers <h3>

# %%
# TODO: Identify Outliers
df['absences'].value_counts()
# Out:
# absences
# 0.000000    115
# 0.026667     65
# 0.053333     54
# 0.080000     30
# 0.106667     22
# 0.133333     17
# 0.186667     12
# 0.160000     12
# 0.040000      8
# 0.093333      7
# 0.213333      7
# 0.240000      5
# 0.066667      5
# 0.266667      4
# 0.173333      3
# 0.200000      3
# 0.013333      3
# 0.293333      3
# 0.120000      3
# 0.146667      3
# 0.373333      1
# 0.320000      1
# 0.720000      1
# 0.333333      1
# 0.746667      1
# 0.346667      1
# 1.000000      1
# 0.280000      1
# 0.253333      1
# 0.400000      1
# 0.506667      1
# 0.533333      1
# 0.306667      1
# 0.226667      1
# Name: count, dtype: int64

# %% [markdown]
# <h3>Remove Outliers</h3>

# %%
plt.figure(figsize=(5,5))
sns.boxplot(df['absences'].values, orient='h',)
# Out:
# <Axes: >

# %% [markdown]
# ##Discover and Visualize the Data to Gain Insights

# %% [markdown]
# <h4>Individual Variables </h4>

# %%
plt.figure(figsize=(5,5))
sns.boxplot(df['absences'].values, orient='h',)
# Out:
# <Axes: >

# %% [markdown]
# <h4>Relationships Between Variables</h4>

# %%
 # TODO: Show relationship between two Variables
plt.figure(figsize=(10, 4))
sns.stripplot(x="famrel", y="absences", data=df);

# %% [markdown]
# <h4>Weak and Strong Relationships<h4>

# %%
# TODO: Show some weak and Strong Relationships
plt.figure(figsize=(22,10))

plt.subplot(231)#subplot to add a subplot to the current figure
sns.regplot(x='G1', y='studytime', data=df,  line_kws={'color': 'red'})

plt.subplot(232)
sns.regplot(x='G2', y='studytime', data=df , line_kws={'color': 'red'})

plt.subplot(233)
sns.regplot(x='G3', y='studytime', data=df,  line_kws={'color': 'red'})
# Out:
# <Axes: xlabel='G3', ylabel='studytime'>

# %% [markdown]
# ##Looking for Correlations

# %% [markdown]
# <h3>Correlation and Causation</h3>
#
# <b> Correlation: </b> a measure of the extent of interdependence between variables.
#
# <b> Causation: </b>the relationship between cause and effect between two variables.
#
# It is important to know the difference between these two and that correlation does not imply causation. Determining correlation is much simpler the determining causation as causation may require independent experimentation.

# %%
# OTDO : Show the Correlation between variables
numeric_df = df.select_dtypes(include=['number'])

# %%
plt.figure(figsize=(5,5))
sns.heatmap(numeric_df.corr(), annot=True, fmt='.1f')
# Out:
# <Axes: >

# %%
print('max studytime : ', df['studytime'].max())
print('min studytime : ', df['studytime'].min())
print('mean studytime :', df['studytime'].mean())
# Out:
# max studytime :  4
# min studytime :  1
# mean studytime : 2.0354430379746837

# %% [markdown]
# #Feature  Engineering

# %% [markdown]
# * Construct new features
# * Combine two features or uncombine a feature
# *	Select features

# %% [markdown]
# <h3>Conclusion: Important Variables</h3>
# We now have a better idea of what our data looks like and which variables are important to take into account when predicting the house price.

# %% [markdown]
# ##Select features

# %%
# TODO: Select the important features
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df_clean =('cleaned_data_student.csv')
df = pd.read_csv(df_clean)

# %%
from google.colab import files
files.download('cleaned_data_student.csv')

# %% [markdown]
# <h3>Save Cleaned Data and Download it <h3>

# %% [markdown]
# #Choose and  fit model

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
X = df.drop("G3", axis=1)
y = df["G3"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.4, random_state=46
)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
from sklearn.ensemble import RandomForestRegressor


model = RandomForestRegressor(
    n_estimators=300,
    max_depth=10,
    random_state=46
)

model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=300, random_state=46)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score

accuracy = r2_score(y_test, y_pred)
print(f"Model Accuracy (R-squared): {accuracy:.2f}")
# Out:
# Model Accuracy (R-squared): 0.91

# %%
y_pred[:4]
# Out:
# array([0.76383333, 0.59095556, 0.57962976, 0.3465    ])

# %%
y_test[:4]
# Out:
# 249    0.75
# 165    0.60
# 275    0.60
# 370    0.45
# Name: G3, dtype: float64
